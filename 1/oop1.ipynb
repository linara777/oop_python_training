# %%
#Джураева Линара, задача 1
class Citizen:

    def __init__(self):
      print(" ")
    

    def setname(self, name):
        self.__name = name
    def setsurname(self, surname):
        self.__surname = surname
    def setage (self, age):
        self.__age = age
    def setethnic (self, ethnic):
        self.__ethnic = ethnic
    def setregistration (self, registration):
        self.__registration = registration

    
    def name(self):
        return self.__name

    def surname(self):
        return self.__surname

    def age(self):
        return self.__age
    def ethnic(self):
        return self.__ethnic

    def registration(self):
        return self.__registration





class Work(Citizen): 

    def setCompanyName(self, CompanyName):
        self.__CompanyName = CompanyName
    def setCompanyAddress(self, CompanyAddress):
        self.__CompanyAddress = CompanyAddress
    def setWorkPhone(self, WorkPhone):
        self.__WorkPhone = WorkPhone

    
    def CompanyName(self):
        return self.__CompanyName

    def CompanyAddress(self):
        return self.__CompanyAddress

    def WorkPhone(self):
        return self.__WorkPhone

class Scientist(Work):
    def setScientificField(self, ScientificField): 
        self.__ScientificField = ScientificField
    def setTypeOfScientist(self, TypeOfScientist):
        self.__TypeOfScientist = TypeOfScientist
    def setNumberOfPublications(self, NumberOfPublications):
        self.__NumberOfPublications = NumberOfPublications

    def ScientificField(self):
        return self.__ScientificField

    def TypeOfScientist(self):
        return self.__TypeOfScientist

    def NumberOfPublications(self):
        return self.__NumberOfPublications

    def Info (self):
        return [self.name(), self.surname(), self.age(), self.ethnic(), self.registration(), self.CompanyName(), self.CompanyAddress(), self.WorkPhone(), self.ScientificField(), self.TypeOfScientist(), self.NumberOfPublications()]




class Master(Scientist):
    pass
class Doctor(Scientist):
     pass
class Candidate(Scientist):
     pass



A = Master()
A.setname('Anna')
A.setsurname('Reser')
A.setage(17)
A.setethnic('british')
A.setregistration('London')
A.setCompanyName('OOOp')
A.setCompanyAddress('London, distant street')
A.setWorkPhone(23456789)
A.setScientificField('Math')
A.setTypeOfScientist('theorist')
A.setNumberOfPublications(34)

B = Doctor()
B.setname('Jane')
B.setsurname('Corle')
B.setage(23)
B.setethnic('british')
B.setregistration('Berlin, close street')
B.setCompanyName('TheBest')
B.setCompanyAddress('Berlin, distant street')
B.setWorkPhone(765)
B.setScientificField('Physics')
B.setTypeOfScientist('calculator')
B.setNumberOfPublications(134)

C = Candidate()
C.setname('John')
C.setsurname('Levinson')
C.setage(57)
C.setethnic('аmerican')
C.setregistration('ew York, 42nd Street')
C.setCompanyName('TheBestCompany')
C.setCompanyAddress('Ney York, 13nd street')
C.setWorkPhone(87437)
C.setScientificField('chemistry')
C.setTypeOfScientist('experimenter')
C.setNumberOfPublications(44.5)


print(A.name(), A.surname(), A.age(), A.ethnic(), A.registration(), A.CompanyName(), A.WorkPhone(), A.ScientificField(), A.TypeOfScientist(), A.NumberOfPublications())

print(B.name(), B.surname(), B.age(), B.ethnic(), B.registration(), B.CompanyName(), B.WorkPhone(), B.ScientificField(), B.TypeOfScientist(), B.NumberOfPublications())
print(C.name(), C.surname(), C.age(), A.ethnic(), C.registration(), C.CompanyName(), C.WorkPhone(), C.ScientificField(), C.TypeOfScientist(), C.NumberOfPublications())
# Out:
#
#
#
# Anna Reser 17 british London OOOp 23456789 Math theorist 34
# Jane Corle 23 british Berlin, close street TheBest 765 Physics calculator 134
# John Levinson 57 british ew York, 42nd Street TheBestCompany 87437 chemistry experimenter 44.5
